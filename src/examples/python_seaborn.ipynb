# %%
# !pip install git+https://github.com/jbosga-ams/oistyle.git@seaborn
# Out:
# Collecting git+https://github.com/jbosga-ams/oistyle.git@seaborn
#   Cloning https://github.com/jbosga-ams/oistyle.git (to revision seaborn) to /tmp/pip-req-build-td1gbq2u
#   Running command git clone -q https://github.com/jbosga-ams/oistyle.git /tmp/pip-req-build-td1gbq2u
#   Running command git checkout -b seaborn --track origin/seaborn
#   Switched to a new branch 'seaborn'
#   Branch 'seaborn' set up to track remote branch 'seaborn' from 'origin'.
# Building wheels for collected packages: oistyle
#   Building wheel for oistyle (setup.py) ... done
#   Created wheel for oistyle: filename=oistyle-0.0.1-py3-none-any.whl size=4806 sha256=fd7b161568633d9b0bd4d98428d9a8fd423b5d84d3b4325e26ed7af7349d24b8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-15azmyqe/wheels/16/5c/4c/c78ebe0bd31a355218800999c40bec253340939b5be79b93eb
# Successfully built oistyle
# Installing collected packages: oistyle
# Successfully installed oistyle-0.0.1

# %% [markdown]
# ### Basic usage
#
# - import colors and templates from oistyle
# - pass template to seaborn.set_style()

# %%
import seaborn as sns
import matplotlib.pylab as plt
import pandas as pd
import plotly.express as px
from oistyle.python.seaborn import base_template, bar_template, line_template, colors

# %%
wide_df = px.data.medals_wide()
wide_df = wide_df.set_index('nation').stack().reset_index()
wide_df.columns = ['nation', 'medal', 'amount']


sns.set_style("white", bar_template)

ax = sns.histplot(wide_df, x='nation', hue='medal', weights='amount',
             multiple='stack', palette=colors["darkblue_lightblue_gradient_5"][:3])
ax = ax.set_ylabel('amount')
